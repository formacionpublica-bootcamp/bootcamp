# %% [markdown]
# # R2-00 · Fundamentos express: Python + pandas — Lección
#
# **Bootcamp de Datos para Funcionarios Públicos · Formación Pública**
# Línea B · *Data Scientist* · Semana 1–2 · Se ejecuta en Google Colab.
#
# > 🚀 **Cómo se trabaja:** lee, ejecuta cada celda con **▶︎** (o `Shift`+`Enter`) y completa los `TODO`. Cada ejercicio termina en una **celda de chequeo** que muestra ✅ si está bien o una pista si todavía no.
#
# ---
#
# ## ¿Qué vas a lograr?
#
# 1. Cargar e **inspeccionar** un DataFrame.
# 2. **Filtrar** filas con máscaras booleanas.
# 3. **Seleccionar** columnas y **ordenar**.
# 4. **Agregar** con `groupby`.
#
# **Competencia de salida:** manipular un DataFrame de datos públicos desde cero, en Colab.
#
# **Dato real:** compras públicas (ChileCompra): monto, categoría, región, tamaño de proveedor.
#
# **Entregable:** que las **4 celdas de chequeo** muestren ✅.

# %%
# ── Preparación del entorno (ejecuta esta celda primero) ──────────────────────
import os, urllib.request
import pandas as pd
import matplotlib.pyplot as plt

# "En vivo o caché": usa el archivo local; si falta (ej. Colab), lo baja del repo.
CSV = "compras_ml.csv"
if not os.path.exists(CSV):
    urllib.request.urlretrieve(f"https://raw.githubusercontent.com/formacionpublica-bootcamp/bootcamp/main/data/compras_ml.csv", CSV)

df = pd.read_csv(CSV)
print("Datos cargados:", df.shape, "filas x columnas")
df.head()

# %% [markdown]
# ### Datos cargados arriba. A manipular el DataFrame.

# %% [markdown]
# ## 1. Cargar e inspeccionar un DataFrame
#
# Un **DataFrame** es una tabla. Lo primero: conocer su forma y columnas con `shape`, `columns`, `head`.

# %% [markdown]
# ### ✍️ Ejercicio 1 — Inspecciona la tabla

# %%
# TODO: n_filas, n_cols a partir de df.shape ; columnas = lista de df.columns
n_filas, n_cols = ...
columnas = ...
print("filas:", n_filas, "| columnas:", columnas)

# %%
# ── Celda de chequeo · Ejercicio 1 ──────────────────────────────────────────
try:
    assert n_filas == len(df)
    assert "monto_total" in columnas
    print("✅ Ejercicio 1: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'df.shape es (filas, columnas); list(df.columns) da los nombres.')
    print("   Detalle:", e)

# %% [markdown]
# ## 2. Filtrar filas con una condición
#
# Una **máscara booleana** selecciona filas. Quedémonos con las compras a proveedores grandes.

# %% [markdown]
# ### ✍️ Ejercicio 2 — Filtra los proveedores Grande

# %%
# TODO: filtra df donde tamano_proveedor sea "Grande"
grandes = ...
n_grandes = len(grandes)
print("compras a proveedores Grande:", n_grandes)

# %%
# ── Celda de chequeo · Ejercicio 2 ──────────────────────────────────────────
try:
    assert (grandes["tamano_proveedor"] == "Grande").all()
    assert n_grandes == int((df["tamano_proveedor"] == "Grande").sum())
    print("✅ Ejercicio 2: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", "df[df['tamano_proveedor'] == 'Grande'].")
    print("   Detalle:", e)

# %% [markdown]
# ## 3. Seleccionar columnas y ordenar
#
# Elegir columnas y **ordenar** para ver lo más relevante: las compras de mayor monto.

# %% [markdown]
# ### ✍️ Ejercicio 3 — Top 10 compras por monto

# %%
# TODO: ordena df por monto_total desc, toma head(10) y las columnas ["categoria", "monto_total"]
top = ...
print(top)

# %%
# ── Celda de chequeo · Ejercicio 3 ──────────────────────────────────────────
try:
    assert list(top.columns) == ["categoria", "monto_total"]
    assert top["monto_total"].is_monotonic_decreasing
    print("✅ Ejercicio 3: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", "df.sort_values('monto_total', ascending=False).head(10)[['categoria','monto_total']].")
    print("   Detalle:", e)

# %% [markdown]
# ## 4. Agregar: una pregunta, una respuesta
#
# **`groupby`** resume por grupo. ¿Cuál es el monto promedio por categoría?

# %% [markdown]
# ### ✍️ Ejercicio 4 — Monto promedio por categoría

# %%
# TODO: agrupa por categoria y calcula la media de monto_total
gasto_categoria = ...
print(gasto_categoria.round(0))

# %%
# ── Celda de chequeo · Ejercicio 4 ──────────────────────────────────────────
try:
    assert len(gasto_categoria) == df["categoria"].nunique()
    assert gasto_categoria.min() >= 0
    print("✅ Ejercicio 4: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", "df.groupby('categoria')['monto_total'].mean().")
    print("   Detalle:", e)

# %%
# (ilustración) Monto promedio por categoría (top 8)
g = gasto_categoria.sort_values().tail(8)
plt.figure(figsize=(6, 4))
plt.barh(g.index, g.values, color="#4240e5")
plt.xlabel("Monto promedio"); plt.title("Promedio por categoría (top 8)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## Cierre
#
# - Un **DataFrame** se inspecciona con `shape`/`columns`/`head` antes de tocarlo.
# - **Máscaras booleanas** filtran filas; `sort_values` ordena; selección con `[[...]]`.
# - **`groupby`** responde preguntas agregadas en una línea.
# - Con esto ya estás listo para la ingeniería de variables de R2-02.
#
# > *Python y pandas just-in-time: lo aprendiste resolviendo preguntas sobre compras públicas reales.*
