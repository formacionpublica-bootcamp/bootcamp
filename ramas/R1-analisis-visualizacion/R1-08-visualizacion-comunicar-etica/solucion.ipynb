# %% [markdown]
# # R1-08 · Visualización para comunicar + ética — Lección
#
# **Bootcamp de Datos para Funcionarios Públicos · Formación Pública**
# Línea A · *Analista de Datos* · Semana 9 · Se ejecuta en Google Colab.
#
# > 🚀 **Cómo se trabaja:** lee, ejecuta cada celda con **▶︎** (o `Shift`+`Enter`) y completa los `TODO`. Cada ejercicio termina en una **celda de chequeo** que muestra ✅ si está bien o una pista si todavía no.
#
# ---
#
# ## ¿Qué vas a lograr?
#
# 1. Hacer barras **honestas** con el eje desde 0.
# 2. Poner **título y etiquetas** claros.
# 3. **Anotar** el dato clave.
# 4. Reconocer y evitar **engaños visuales**.
#
# **Competencia de salida:** comunicar un hallazgo con un gráfico claro y honesto para una audiencia directiva.
#
# **Dato real:** gasto en compras públicas por región (ChileCompra).
#
# **Entregable:** que las **4 celdas de chequeo** muestren ✅.

# %%
# ── Preparación del entorno (ejecuta esta celda primero) ──────────────────────
import os, urllib.request
import pandas as pd
import matplotlib.pyplot as plt

# "En vivo o caché": usa el archivo local; si falta (ej. Colab), lo baja del repo.
CSV = "compras_ml.csv"
if not os.path.exists(CSV):
    urllib.request.urlretrieve(f"https://raw.githubusercontent.com/formacionpublica-bootcamp/bootcamp/main/data/compras_ml.csv", CSV)

df = pd.read_csv(CSV)
print("Datos cargados:", df.shape, "filas x columnas")
df.head()

# %% [markdown]
# ### Preparación

# %%
# Trabajaremos con el gasto por región (top 6) en todos los ejercicios.
g = df.groupby("region_comprador")["monto_total"].sum().sort_values(ascending=False).head(6)
print(g.round(0))

# %% [markdown]
# ## 1. El eje Y empieza en cero
#
# El engaño visual más común es **truncar el eje Y**: exagera diferencias pequeñas. Un gráfico de barras honesto **empieza en 0**.

# %% [markdown]
# ### ✍️ Ejercicio 1 — Dibuja barras con el eje desde 0

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(g.index, g.values, color="#4240e5")
ax.set_ylim(bottom=0)
plt.xticks(rotation=45, ha="right"); plt.tight_layout()
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 1 ──────────────────────────────────────────
try:
    assert ax.get_ylim()[0] == 0
    print("✅ Ejercicio 1: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'ax.set_ylim(bottom=0).')
    print("   Detalle:", e)

# %% [markdown]
# ## 2. Título y etiquetas: que se entienda solo
#
# Un gráfico para otros necesita **título** y **etiquetas de ejes**: debe entenderse sin explicación oral.

# %% [markdown]
# ### ✍️ Ejercicio 2 — Agrega título y etiquetas

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(g.index, g.values, color="#4240e5")
ax.set_ylim(bottom=0)
ax.set_title("Gasto en compras públicas por región (top 6)")
ax.set_xlabel("Región"); ax.set_ylabel("Gasto total (CLP)")
plt.xticks(rotation=45, ha="right"); plt.tight_layout()
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 2 ──────────────────────────────────────────
try:
    assert ax.get_title() != ""
    assert ax.get_xlabel() != "" and ax.get_ylabel() != ""
    print("✅ Ejercicio 2: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'ax.set_title(...), ax.set_xlabel(...), ax.set_ylabel(...).')
    print("   Detalle:", e)

# %% [markdown]
# ## 3. Anotar el dato clave
#
# Una buena visualización **guía la mirada** al mensaje. Anota el valor más importante.

# %% [markdown]
# ### ✍️ Ejercicio 3 — Anota la región de mayor gasto

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.bar(g.index, g.values, color="#4240e5")
ax.set_ylim(bottom=0)
ax.annotate(f"Mayor gasto: {g.idxmax()}", xy=(0, g.max()), xytext=(1, g.max() * 0.9),
            arrowprops=dict(arrowstyle="->"))
plt.xticks(rotation=45, ha="right"); plt.tight_layout()
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 3 ──────────────────────────────────────────
try:
    assert len(ax.texts) > 0
    print("✅ Ejercicio 3: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", "ax.annotate('texto', xy=(...), xytext=(...)).")
    print("   Detalle:", e)

# %% [markdown]
# ## 4. Engañoso vs honesto, lado a lado
#
# Comparemos el mismo dato con eje **truncado** (engañoso) y desde **cero** (honesto). La diferencia es ética, no estética.

# %% [markdown]
# ### ✍️ Ejercicio 4 — Construye las dos versiones

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(11, 4))
ax1.bar(g.index, g.values, color="#ff6b35"); ax1.set_ylim(bottom=g.min() * 0.98); ax1.set_title("Enganoso (eje truncado)")
ax2.bar(g.index, g.values, color="#4240e5"); ax2.set_ylim(bottom=0); ax2.set_title("Honesto (desde 0)")
for a in (ax1, ax2):
    a.set_xticklabels(g.index, rotation=45, ha="right")
honesto_desde_cero = ax2.get_ylim()[0] == 0
plt.tight_layout(); plt.show()

# %%
# ── Celda de chequeo · Ejercicio 4 ──────────────────────────────────────────
try:
    assert honesto_desde_cero
    assert ax1.get_ylim()[0] > 0
    print("✅ Ejercicio 4: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'En ax2: ax2.set_ylim(bottom=0).')
    print("   Detalle:", e)

# %% [markdown]
# ## Cierre
#
# - Barras **desde 0**: truncar el eje es el engaño más común.
# - **Título y etiquetas** hacen que el gráfico se entienda solo.
# - **Anota** el mensaje clave para guiar la mirada.
# - La honestidad visual es **ética**: en el Estado, comunicar bien es comunicar con integridad.
#
# > *Ética distribuida: aquí la responsabilidad es no engañar con un gráfico, aunque sea sin querer.*
