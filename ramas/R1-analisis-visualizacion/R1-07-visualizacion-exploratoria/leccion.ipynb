# %% [markdown]
# # R1-07 · Visualización exploratoria — ver para entender — Lección
#
# **Bootcamp de Datos para Funcionarios Públicos · Formación Pública**
# Línea A · *Analista de Datos* · Semana 8 · Se ejecuta en Google Colab.
#
# > 🚀 **Cómo se trabaja:** lee, ejecuta cada celda con **▶︎** (o `Shift`+`Enter`) y completa los `TODO`. Cada ejercicio termina en una **celda de chequeo** que muestra ✅ si está bien o una pista si todavía no.
#
# ---
#
# ## ¿Qué vas a lograr?
#
# 1. Leer la **forma** de una variable con histogramas.
# 2. Comparar grupos con **boxplots**.
# 3. Detectar relaciones con **dispersión**.
# 4. Comparar categorías con **barras**.
#
# **Competencia de salida:** usar gráficos para descubrir patrones en datos públicos.
#
# **Dato real:** compras públicas (ChileCompra): monto, cantidad, región, tamaño de proveedor.
#
# **Entregable:** que las **4 celdas de chequeo** muestren ✅.

# %%
# ── Preparación del entorno (ejecuta esta celda primero) ──────────────────────
import os, urllib.request
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

# "En vivo o caché": usa el archivo local; si falta (ej. Colab), lo baja del repo.
CSV = "compras_ml.csv"
if not os.path.exists(CSV):
    urllib.request.urlretrieve(f"https://raw.githubusercontent.com/formacionpublica-bootcamp/bootcamp/main/data/compras_ml.csv", CSV)

df = pd.read_csv(CSV)
print("Datos cargados:", df.shape, "filas x columnas")
df.head()

# %% [markdown]
# ### Datos cargados arriba. Exploremos viendo.

# %% [markdown]
# ## 1. Histograma: la forma de una variable
#
# El **histograma** muestra cómo se distribuye un número. El monto de compras tiene cola larga (recortamos al p99 para verlo mejor).

# %% [markdown]
# ### ✍️ Ejercicio 1 — Dibuja el histograma del monto

# %%
montos = df["monto_total"].clip(upper=df["monto_total"].quantile(0.99))
fig, ax = plt.subplots(figsize=(6, 4))
# TODO: dibuja un histograma de 'montos' con 40 bins
...
ax.set_xlabel("Monto (recortado al p99)"); ax.set_ylabel("Frecuencia"); ax.set_title("Distribución del monto")
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 1 ──────────────────────────────────────────
try:
    assert fig.__class__.__name__ == "Figure"
    assert len(ax.patches) > 0
    print("✅ Ejercicio 1: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'ax.hist(montos, bins=40).')
    print("   Detalle:", e)

# %% [markdown]
# ## 2. Boxplot: comparar grupos
#
# El **boxplot** compara la distribución entre grupos. ¿Difiere el monto según el tamaño del proveedor?

# %% [markdown]
# ### ✍️ Ejercicio 2 — Boxplot del monto por tamaño

# %%
orden = ["Micro", "Pequeña", "Mediana", "Grande"]
tope = df["monto_total"].quantile(0.99)
grupos = [df[df["tamano_proveedor"] == t]["monto_total"].clip(upper=tope) for t in orden]
fig, ax = plt.subplots(figsize=(6, 4))
# TODO: dibuja un boxplot de 'grupos' con labels=orden
...
ax.set_ylabel("Monto"); ax.set_title("Monto por tamaño de proveedor")
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 2 ──────────────────────────────────────────
try:
    assert fig.__class__.__name__ == "Figure"
    assert len(grupos) == 4
    print("✅ Ejercicio 2: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'ax.boxplot(grupos, labels=orden).')
    print("   Detalle:", e)

# %% [markdown]
# ## 3. Dispersión: ¿se relacionan dos variables?
#
# El **gráfico de dispersión** revela relaciones. ¿Más cantidad implica más monto?

# %% [markdown]
# ### ✍️ Ejercicio 3 — Dispersión cantidad vs monto

# %%
m = df.sample(800, random_state=42)
fig, ax = plt.subplots(figsize=(6, 4))
# TODO: dibuja un scatter de m["cantidad"] vs m["monto_total"]
...
ax.set_xlabel("Cantidad"); ax.set_ylabel("Monto"); ax.set_title("Cantidad vs monto")
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 3 ──────────────────────────────────────────
try:
    assert fig.__class__.__name__ == "Figure"
    assert len(ax.collections) > 0
    print("✅ Ejercicio 3: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", "ax.scatter(m['cantidad'], m['monto_total']).")
    print("   Detalle:", e)

# %% [markdown]
# ## 4. Barras: comparar categorías
#
# Las **barras** comparan magnitudes entre categorías. ¿Qué región concentra más gasto?

# %% [markdown]
# ### ✍️ Ejercicio 4 — Gasto por región (barras horizontales)

# %%
g = df.groupby("region_comprador")["monto_total"].sum().sort_values()
fig, ax = plt.subplots(figsize=(6, 5))
# TODO: dibuja barras horizontales (barh) con g.index y g.values
...
ax.set_xlabel("Gasto total"); ax.set_title("Gasto por región")
plt.show()

# %%
# ── Celda de chequeo · Ejercicio 4 ──────────────────────────────────────────
try:
    assert fig.__class__.__name__ == "Figure"
    assert len(g) == df["region_comprador"].nunique()
    print("✅ Ejercicio 4: ¡correcto!")
except Exception as e:
    print("❌ Aún no. Revisa tu respuesta y vuelve a intentarlo.")
    print("   Pista:", 'ax.barh(g.index, g.values).')
    print("   Detalle:", e)

# %% [markdown]
# ## Cierre
#
# - El **histograma** muestra la forma; el **boxplot** compara grupos.
# - La **dispersión** revela relaciones; las **barras** comparan categorías.
# - Esta visualización es para **descubrir** (para ti). En R1-08 aprenderás a **comunicar** (para otros).
#
# > *Ver para entender: una victoria temprana — un buen gráfico vale más que una tabla de números.*
